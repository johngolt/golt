# %%
import pyecharts
pyecharts.__version__
# Out:
# '1.1.0'

# %% [markdown]
# 全局设置（`set_global_opts()`)
# -TitleOpts:标题配置项
# - LegendOpts:图例配置项
# - ToolboxOpts:工具箱配置项
# - VisualMapOpts:视觉映射配置项
# - TooltipOpts: 提示框配置项
# - DataZoomOpts:区域缩放配置项
#
# 系列配置(`set_series_opts`)控制图表的文本、线条样式、标记等。

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
cate = ['Apple', 'Huawei', 'Xiaomi', 'Oppo', 'Vivo', 'Meizu']
data1 = [123, 153, 89, 107, 98, 23]
data2 = [56, 77, 93, 68, 45, 67]
bar = (Bar()
       .add_xaxis(cate)
       .add_yaxis('电商渠道', data1)
       .add_yaxis('门店', data2)
       .set_series_opts(label_opts=opts.LabelOpts(is_show=False),
                        markpoint_opts=opts.MarkPointOpts(data=[opts.MarkPointItem(type_="max", name="最大值"),]))
       .set_global_opts(title_opts=opts.TitleOpts(title="Bar-基本示例", subtitle="我是副标题"))
      )

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="f5bb7255aa78422b8f18b1c58f8fe3fe" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_f5bb7255aa78422b8f18b1c58f8fe3fe = echarts.init(
#             document.getElementById('f5bb7255aa78422b8f18b1c58f8fe3fe'), 'white', {renderer: 'canvas'});
#         var option_f5bb7255aa78422b8f18b1c58f8fe3fe = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u7535\u5546\u6e20\u9053",
#             "data": [
#                 123,
#                 153,
#                 89,
#                 107,
#                 98,
#                 23
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8,
#                 "fontSize": 12
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8,
#                     "fontSize": 12
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u95e8\u5e97",
#             "data": [
#                 56,
#                 77,
#                 93,
#                 68,
#                 45,
#                 67
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8,
#                 "fontSize": 12
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8,
#                     "fontSize": 12
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7535\u5546\u6e20\u9053",
#                 "\u95e8\u5e97"
#             ],
#             "selected": {
#                 "\u7535\u5546\u6e20\u9053": true,
#                 "\u95e8\u5e97": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "Apple",
#                 "Huawei",
#                 "Xiaomi",
#                 "Oppo",
#                 "Vivo",
#                 "Meizu"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-\u57fa\u672c\u793a\u4f8b",
#             "subtext": "\u6211\u662f\u526f\u6807\u9898"
#         }
#     ]
# };
#         chart_f5bb7255aa78422b8f18b1c58f8fe3fe.setOption(option_f5bb7255aa78422b8f18b1c58f8fe3fe);
#     });
# </script>

# %%
#饼图
from pyecharts.charts import Pie
from pyecharts import options as opts

# 示例数据
cate = ['Apple', 'Huawei', 'Xiaomi', 'Oppo', 'Vivo', 'Meizu']
data = [153, 124, 107, 99, 89, 46]
pie = (Pie()
       .add('', [list(z) for z in zip(cate, data)],
            radius=["30%", "75%"],
            rosetype="radius")
       .set_global_opts(title_opts=opts.TitleOpts(title="Pie-基本示例", subtitle="我是副标题"))
       .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {d}%"))
      )

pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="78de783c41e34669a3f386bdd07be4b0" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_78de783c41e34669a3f386bdd07be4b0 = echarts.init(
#             document.getElementById('78de783c41e34669a3f386bdd07be4b0'), 'white', {renderer: 'canvas'});
#         var option_78de783c41e34669a3f386bdd07be4b0 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "Apple",
#                     "value": 153
#                 },
#                 {
#                     "name": "Huawei",
#                     "value": 124
#                 },
#                 {
#                     "name": "Xiaomi",
#                     "value": 107
#                 },
#                 {
#                     "name": "Oppo",
#                     "value": 99
#                 },
#                 {
#                     "name": "Vivo",
#                     "value": 89
#                 },
#                 {
#                     "name": "Meizu",
#                     "value": 46
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "fontSize": 12,
#                 "formatter": "{b}: {d}%"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Apple",
#                 "Huawei",
#                 "Xiaomi",
#                 "Oppo",
#                 "Vivo",
#                 "Meizu"
#             ],
#             "selected": {},
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-\u57fa\u672c\u793a\u4f8b",
#             "subtext": "\u6211\u662f\u526f\u6807\u9898"
#         }
#     ]
# };
#         chart_78de783c41e34669a3f386bdd07be4b0.setOption(option_78de783c41e34669a3f386bdd07be4b0);
#     });
# </script>

# %%
#折线图
from pyecharts.charts import Line
from pyecharts import options as opts

# 示例数据
cate = ['Apple', 'Huawei', 'Xiaomi', 'Oppo', 'Vivo', 'Meizu']
data1 = [123, 153, 89, 107, 98, 23]
data2 = [56, 77, 93, 68, 45, 67]
"""
折线图示例:
1. is_smooth 折线 OR 平滑
2. markline_opts 标记线 OR 标记点
"""
line = (Line()
       .add_xaxis(cate)
       .add_yaxis('电商渠道', data1, 
                  markline_opts=opts.MarkLineOpts(data=[opts.MarkLineItem(type_="average")]))
       .add_yaxis('门店', data2, 
                  is_smooth=True, 
                  markpoint_opts=opts.MarkPointOpts(data=[opts.MarkPointItem(name="自定义标记点", 
                                                                             coord=[cate[2], data2[2]], value=data2[2])]))
       .set_global_opts(title_opts=opts.TitleOpts(title="Line-基本示例", subtitle="我是副标题"))
      )

line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="30b0472d69654c5e90b526fde867c039" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_30b0472d69654c5e90b526fde867c039 = echarts.init(
#             document.getElementById('30b0472d69654c5e90b526fde867c039'), 'white', {renderer: 'canvas'});
#         var option_30b0472d69654c5e90b526fde867c039 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u7535\u5546\u6e20\u9053",
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "Apple",
#                     123
#                 ],
#                 [
#                     "Huawei",
#                     153
#                 ],
#                 [
#                     "Xiaomi",
#                     89
#                 ],
#                 [
#                     "Oppo",
#                     107
#                 ],
#                 [
#                     "Vivo",
#                     98
#                 ],
#                 [
#                     "Meizu",
#                     23
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "fontSize": 12
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8,
#                     "fontSize": 12
#                 },
#                 "data": [
#                     {
#                         "type": "average"
#                     }
#                 ]
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u95e8\u5e97",
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": true,
#             "step": false,
#             "data": [
#                 [
#                     "Apple",
#                     56
#                 ],
#                 [
#                     "Huawei",
#                     77
#                 ],
#                 [
#                     "Xiaomi",
#                     93
#                 ],
#                 [
#                     "Oppo",
#                     68
#                 ],
#                 [
#                     "Vivo",
#                     45
#                 ],
#                 [
#                     "Meizu",
#                     67
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "fontSize": 12
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8,
#                     "fontSize": 12
#                 },
#                 "data": [
#                     {
#                         "name": "\u81ea\u5b9a\u4e49\u6807\u8bb0\u70b9",
#                         "coord": [
#                             "Xiaomi",
#                             93
#                         ],
#                         "value": 93
#                     }
#                 ]
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7535\u5546\u6e20\u9053",
#                 "\u95e8\u5e97"
#             ],
#             "selected": {
#                 "\u7535\u5546\u6e20\u9053": true,
#                 "\u95e8\u5e97": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "Apple",
#                 "Huawei",
#                 "Xiaomi",
#                 "Oppo",
#                 "Vivo",
#                 "Meizu"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "Line-\u57fa\u672c\u793a\u4f8b",
#             "subtext": "\u6211\u662f\u526f\u6807\u9898"
#         }
#     ]
# };
#         chart_30b0472d69654c5e90b526fde867c039.setOption(option_30b0472d69654c5e90b526fde867c039);
#     });
# </script>

# %%
#漏斗图
from pyecharts.charts import Funnel
from pyecharts import options as opts

# 示例数据
cate = ['访问', '注册', '加入购物车', '提交订单', '付款成功']
data = [30398, 15230, 10045, 8109, 5698]
"""
漏斗图示例：
1. sort_控制排序，默认降序；
2. 标签显示位置
"""
funnel = (Funnel()
          .add("用户数", [list(z) for z in zip(cate, data)], 
               sort_='ascending',
               label_opts=opts.LabelOpts(position="inside"))
          .set_global_opts(title_opts=opts.TitleOpts(title="Funnel-基本示例", subtitle="我是副标题"))
         )

funnel.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="8b733090a37f4db3b8fdb708e3d3b9d5" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_8b733090a37f4db3b8fdb708e3d3b9d5 = echarts.init(
#             document.getElementById('8b733090a37f4db3b8fdb708e3d3b9d5'), 'white', {renderer: 'canvas'});
#         var option_8b733090a37f4db3b8fdb708e3d3b9d5 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u7528\u6237\u6570",
#             "data": [
#                 {
#                     "name": "\u8bbf\u95ee",
#                     "value": 30398
#                 },
#                 {
#                     "name": "\u6ce8\u518c",
#                     "value": 15230
#                 },
#                 {
#                     "name": "\u52a0\u5165\u8d2d\u7269\u8f66",
#                     "value": 10045
#                 },
#                 {
#                     "name": "\u63d0\u4ea4\u8ba2\u5355",
#                     "value": 8109
#                 },
#                 {
#                     "name": "\u4ed8\u6b3e\u6210\u529f",
#                     "value": 5698
#                 }
#             ],
#             "sort": "ascending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "fontSize": 12
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8bbf\u95ee",
#                 "\u4ed8\u6b3e\u6210\u529f",
#                 "\u52a0\u5165\u8d2d\u7269\u8f66",
#                 "\u6ce8\u518c",
#                 "\u63d0\u4ea4\u8ba2\u5355"
#             ],
#             "selected": {
#                 "\u8bbf\u95ee": true,
#                 "\u6ce8\u518c": true,
#                 "\u52a0\u5165\u8d2d\u7269\u8f66": true,
#                 "\u63d0\u4ea4\u8ba2\u5355": true,
#                 "\u4ed8\u6b3e\u6210\u529f": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Funnel-\u57fa\u672c\u793a\u4f8b",
#             "subtext": "\u6211\u662f\u526f\u6807\u9898"
#         }
#     ]
# };
#         chart_8b733090a37f4db3b8fdb708e3d3b9d5.setOption(option_8b733090a37f4db3b8fdb708e3d3b9d5);
#     });
# </script>

# %%
# 热力图
from pyecharts.charts import HeatMap
from pyecharts import options as opts
from pyecharts.faker import Faker
import random

# 示例数据
data = [[i, j, random.randint(0, 50)] for i in range(24) for j in range(7)]
heat = (HeatMap()
        .add_xaxis(Faker.clock)
        .add_yaxis("访客数", 
                   Faker.week, 
                   data,
                   label_opts=opts.LabelOpts(is_show=True, position="inside"))
        .set_global_opts(
            title_opts=opts.TitleOpts(title="HeatMap-基本示例", subtitle="我是副标题"),
            visualmap_opts=opts.VisualMapOpts(),
            legend_opts=opts.LegendOpts(is_show=False))
       )

heat.render_notebook()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-4855d60fd818> in <module>()
#       1 from pyecharts.charts import HeatMap
#       2 from pyecharts import options as opts
# ----> 3 from pyecharts.faker import Faker
#       4 import random
#       5
#
# ModuleNotFoundError: No module named 'pyecharts.faker'

# %%
#地理图
from pyecharts import options as opts
from pyecharts.charts import Map
import random

province = ['广东', '湖北', '湖南', '四川', '重庆', '黑龙江', '浙江', '山西', '河北', '安徽', '河南', '山东', '西藏']
data = [(i, random.randint(50, 150)) for i in province]
_map = (
        Map()
        .add("销售额", data, "china")
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Map-基本示例"),
            legend_opts=opts.LegendOpts(is_show=False),
            visualmap_opts=opts.VisualMapOpts(max_=200, is_piecewise=True),
        )
    )

_map.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#     <div id="b9b9cb9198d24b70a16e88f5753a0a92" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#         var chart_b9b9cb9198d24b70a16e88f5753a0a92 = echarts.init(
#             document.getElementById('b9b9cb9198d24b70a16e88f5753a0a92'), 'white', {renderer: 'canvas'});
#         var option_b9b9cb9198d24b70a16e88f5753a0a92 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u9500\u552e\u989d",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "fontSize": 12
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 52
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 131
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 149
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 126
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 87
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 141
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 126
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 137
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 69
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 113
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 107
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 60
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 57
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u9500\u552e\u989d"
#             ],
#             "selected": {
#                 "\u9500\u552e\u989d": true
#             },
#             "show": false
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Map-\u57fa\u672c\u793a\u4f8b"
#         }
#     ],
#     "visualMap": {
#         "type": "piecewise",
#         "min": 0,
#         "max": 200,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true
#     }
# };
#         chart_b9b9cb9198d24b70a16e88f5753a0a92.setOption(option_b9b9cb9198d24b70a16e88f5753a0a92);
#     });
# </script>

# %%
#地理热点图
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.globals import ChartType
import random

province = ['武汉', '十堰', '鄂州', '宜昌', '荆州', '孝感', '黄石', '咸宁', '仙桃']
data = [(i, random.randint(50, 150)) for i in province]
geo = (Geo().
        add_schema(maptype="湖北")
        .add("门店数", data,type_=ChartType.HEATMAP)
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(
            visualmap_opts=opts.VisualMapOpts(),
            legend_opts=opts.LegendOpts(is_show=False),
            title_opts=opts.TitleOpts(title="Geo-湖北热力地图"))
      )

geo.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '湖北':'https://assets.pyecharts.org/assets/maps/hubei'
#         }
#     });
# </script>
#
#     <div id="e460bbd458644ac1bbead734e5cc5f93" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', '湖北'], function(echarts) {
#         var chart_e460bbd458644ac1bbead734e5cc5f93 = echarts.init(
#             document.getElementById('e460bbd458644ac1bbead734e5cc5f93'), 'white', {renderer: 'canvas'});
#         var option_e460bbd458644ac1bbead734e5cc5f93 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "name": "\u95e8\u5e97\u6570",
#             "coordinateSystem": "geo",
#             "data": [
#                 {
#                     "name": "\u6b66\u6c49",
#                     "value": [
#                         114.31,
#                         30.52,
#                         119
#                     ]
#                 },
#                 {
#                     "name": "\u5341\u5830",
#                     "value": [
#                         110.47,
#                         32.4,
#                         113
#                     ]
#                 },
#                 {
#                     "name": "\u9102\u5dde",
#                     "value": [
#                         114.52,
#                         30.23,
#                         102
#                     ]
#                 },
#                 {
#                     "name": "\u5b9c\u660c",
#                     "value": [
#                         111.3,
#                         30.7,
#                         106
#                     ]
#                 },
#                 {
#                     "name": "\u8346\u5dde",
#                     "value": [
#                         112.239741,
#                         30.335165,
#                         134
#                     ]
#                 },
#                 {
#                     "name": "\u5b5d\u611f",
#                     "value": [
#                         113.54,
#                         30.56,
#                         90
#                     ]
#                 },
#                 {
#                     "name": "\u9ec4\u77f3",
#                     "value": [
#                         115.06,
#                         30.12,
#                         86
#                     ]
#                 },
#                 {
#                     "name": "\u54b8\u5b81",
#                     "value": [
#                         114.17,
#                         29.53,
#                         51
#                     ]
#                 },
#                 {
#                     "name": "\u4ed9\u6843",
#                     "value": [
#                         113.27,
#                         30.22,
#                         116
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8,
#                 "fontSize": 12
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u95e8\u5e97\u6570"
#             ],
#             "selected": {
#                 "\u95e8\u5e97\u6570": true
#             },
#             "show": false
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Geo-\u6e56\u5317\u70ed\u529b\u5730\u56fe"
#         }
#     ],
#     "visualMap": {
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true
#     },
#     "geo": {
#         "map": "\u6e56\u5317",
#         "roam": true,
#         "emphasis": {}
#     }
# };
#         chart_e460bbd458644ac1bbead734e5cc5f93.setOption(option_e460bbd458644ac1bbead734e5cc5f93);
#     });
# </script>

# %%
#3D散点图
from pyecharts import options as opts
from pyecharts.charts import Scatter3D
from pyecharts.faker import Faker
import random


data = [(random.randint(0, 100), random.randint(0, 100), random.randint(0, 100))
        for _ in range(80)]
scatter3D = (Scatter3D()
             .add("", data)
             .set_global_opts(
                 title_opts=opts.TitleOpts("Scatter3D-基本示例"),
                 visualmap_opts=opts.VisualMapOpts(range_color=Faker.visual_color))
            )

scatter3D.render_notebook()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-97dc5b4ddc97> in <module>()
#       1 from pyecharts import options as opts
#       2 from pyecharts.charts import Scatter3D
# ----> 3 from pyecharts.faker import Faker
#       4 import random
#       5
#
# ModuleNotFoundError: No module named 'pyecharts.faker'

# %%
#XY轴翻转
from pyecharts.charts import Bar
from pyecharts import options as opts

# 示例数据
cate = ['Apple', 'Huawei', 'Xiaomi', 'Oppo', 'Vivo', 'Meizu']
data1 = [123, 153, 89, 107, 98, 23]
data2 = [56, 77, 93, 68, 45, 67]
bar = (Bar()
       .add_xaxis(cate)
       .add_yaxis('电商渠道', data1)
       .add_yaxis('门店', data2)
       .set_global_opts(title_opts=opts.TitleOpts(title="XY轴翻转-基本示例", subtitle="我是副标题"))
       .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
       .reversal_axis()
      )

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="37b18989a4dc4c7cb9adfc2161180085" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_37b18989a4dc4c7cb9adfc2161180085 = echarts.init(
#             document.getElementById('37b18989a4dc4c7cb9adfc2161180085'), 'white', {renderer: 'canvas'});
#         var option_37b18989a4dc4c7cb9adfc2161180085 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u7535\u5546\u6e20\u9053",
#             "data": [
#                 123,
#                 153,
#                 89,
#                 107,
#                 98,
#                 23
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8,
#                 "fontSize": 12
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u95e8\u5e97",
#             "data": [
#                 56,
#                 77,
#                 93,
#                 68,
#                 45,
#                 67
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8,
#                 "fontSize": 12
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7535\u5546\u6e20\u9053",
#                 "\u95e8\u5e97"
#             ],
#             "selected": {
#                 "\u7535\u5546\u6e20\u9053": true,
#                 "\u95e8\u5e97": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "Apple",
#                 "Huawei",
#                 "Xiaomi",
#                 "Oppo",
#                 "Vivo",
#                 "Meizu"
#             ]
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "XY\u8f74\u7ffb\u8f6c-\u57fa\u672c\u793a\u4f8b",
#             "subtext": "\u6211\u662f\u526f\u6807\u9898"
#         }
#     ]
# };
#         chart_37b18989a4dc4c7cb9adfc2161180085.setOption(option_37b18989a4dc4c7cb9adfc2161180085);
#     });
# </script>

# %%
#组合图表
from pyecharts import options as opts
from pyecharts.charts import Map, Bar, Grid
from pyecharts.globals import ChartType, ThemeType
import random

province = ['武汉', '十堰', '鄂州', '宜昌', '荆州', '孝感', '黄石', '咸宁', '仙桃']
data = [324, 125, 145, 216, 241, 244, 156, 278, 169]
bar = (Bar()
       .add_xaxis(province)
       .add_yaxis('营业额', data)
       .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
       .set_global_opts(
            title_opts=opts.TitleOpts(title="Grid-Bar")
        )
      )

line = (Line()
       .add_xaxis(province)
       .add_yaxis('营业额', data, 
                  markline_opts=opts.MarkLineOpts(data=[opts.MarkLineItem(type_="average")]))
       .set_global_opts(title_opts=opts.TitleOpts(title="Grid-Line", pos_top="48%"))
      )

grid = (
        Grid()
        .add(bar, grid_opts=opts.GridOpts(pos_bottom="60%"))
        .add(line, grid_opts=opts.GridOpts(pos_top="60%"))
    )

grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="91fcb6ffedf84aa9bb63bf1c01428ae9" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_91fcb6ffedf84aa9bb63bf1c01428ae9 = echarts.init(
#             document.getElementById('91fcb6ffedf84aa9bb63bf1c01428ae9'), 'white', {renderer: 'canvas'});
#         var option_91fcb6ffedf84aa9bb63bf1c01428ae9 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u8425\u4e1a\u989d",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "data": [
#                 324,
#                 125,
#                 145,
#                 216,
#                 241,
#                 244,
#                 156,
#                 278,
#                 169
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8,
#                 "fontSize": 12
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u8425\u4e1a\u989d",
#             "xAxisIndex": 1,
#             "yAxisIndex": 1,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u6b66\u6c49",
#                     324
#                 ],
#                 [
#                     "\u5341\u5830",
#                     125
#                 ],
#                 [
#                     "\u9102\u5dde",
#                     145
#                 ],
#                 [
#                     "\u5b9c\u660c",
#                     216
#                 ],
#                 [
#                     "\u8346\u5dde",
#                     241
#                 ],
#                 [
#                     "\u5b5d\u611f",
#                     244
#                 ],
#                 [
#                     "\u9ec4\u77f3",
#                     156
#                 ],
#                 [
#                     "\u54b8\u5b81",
#                     278
#                 ],
#                 [
#                     "\u4ed9\u6843",
#                     169
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "fontSize": 12
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8,
#                     "fontSize": 12
#                 },
#                 "data": [
#                     {
#                         "type": "average"
#                     }
#                 ]
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8425\u4e1a\u989d"
#             ],
#             "selected": {
#                 "\u8425\u4e1a\u989d": true
#             },
#             "show": true
#         },
#         {
#             "data": [
#                 "\u8425\u4e1a\u989d"
#             ],
#             "selected": {
#                 "\u8425\u4e1a\u989d": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         },
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 1,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6b66\u6c49",
#                 "\u5341\u5830",
#                 "\u9102\u5dde",
#                 "\u5b9c\u660c",
#                 "\u8346\u5dde",
#                 "\u5b5d\u611f",
#                 "\u9ec4\u77f3",
#                 "\u54b8\u5b81",
#                 "\u4ed9\u6843"
#             ]
#         },
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 1,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6b66\u6c49",
#                 "\u5341\u5830",
#                 "\u9102\u5dde",
#                 "\u5b9c\u660c",
#                 "\u8346\u5dde",
#                 "\u5b5d\u611f",
#                 "\u9ec4\u77f3",
#                 "\u54b8\u5b81",
#                 "\u4ed9\u6843"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "Grid-Bar"
#         },
#         {
#             "text": "Grid-Line",
#             "top": "48%"
#         }
#     ],
#     "grid": [
#         {
#             "bottom": "60%"
#         },
#         {
#             "top": "60%"
#         }
#     ]
# };
#         chart_91fcb6ffedf84aa9bb63bf1c01428ae9.setOption(option_91fcb6ffedf84aa9bb63bf1c01428ae9);
#     });
# </script>

# %%
# 主题配置
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.globals import ThemeType

# 示例数据
cate = ['Apple', 'Huawei', 'Xiaomi', 'Oppo', 'Vivo', 'Meizu']
data1 = [123, 153, 89, 107, 98, 23]
data2 = [56, 77, 93, 68, 45, 67]
"""
主题设置：
默认white
"""
bar = (Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMANTIC))
       .add_xaxis(cate)
       .add_yaxis('电商渠道', data1)
       .add_yaxis('门店', data2)
       .set_series_opts(label_opts=opts.LabelOpts(is_show=False),
                        markpoint_opts=opts.MarkPointOpts(data=[opts.MarkPointItem(type_="max", name="最大值"),]))
       .set_global_opts(title_opts=opts.TitleOpts(title="Theme-ROMANTIC"))
      )

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'romantic':'https://assets.pyecharts.org/assets/themes/romantic'
#         }
#     });
# </script>
#
#     <div id="bcec67094f3b4f0f8465eea3e10cdd84" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'romantic'], function(echarts) {
#         var chart_bcec67094f3b4f0f8465eea3e10cdd84 = echarts.init(
#             document.getElementById('bcec67094f3b4f0f8465eea3e10cdd84'), 'romantic', {renderer: 'canvas'});
#         var option_bcec67094f3b4f0f8465eea3e10cdd84 = {
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u7535\u5546\u6e20\u9053",
#             "data": [
#                 123,
#                 153,
#                 89,
#                 107,
#                 98,
#                 23
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8,
#                 "fontSize": 12
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8,
#                     "fontSize": 12
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u95e8\u5e97",
#             "data": [
#                 56,
#                 77,
#                 93,
#                 68,
#                 45,
#                 67
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8,
#                 "fontSize": 12
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8,
#                     "fontSize": 12
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7535\u5546\u6e20\u9053",
#                 "\u95e8\u5e97"
#             ],
#             "selected": {
#                 "\u7535\u5546\u6e20\u9053": true,
#                 "\u95e8\u5e97": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "Apple",
#                 "Huawei",
#                 "Xiaomi",
#                 "Oppo",
#                 "Vivo",
#                 "Meizu"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "Theme-ROMANTIC"
#         }
#     ]
# };
#         chart_bcec67094f3b4f0f8465eea3e10cdd84.setOption(option_bcec67094f3b4f0f8465eea3e10cdd84);
#     });
# </script>

# %%
#时间轴
from pyecharts import options as opts
from pyecharts.charts import Bar, Timeline
from pyecharts.globals import ThemeType

# 示例数据
cate = ['Apple', 'Huawei', 'Xiaomi', 'Oppo', 'Vivo', 'Meizu']
tl = Timeline()
for i in range(2015, 2020):
    bar = (
        Bar()
        .add_xaxis(cate)
        .add_yaxis("线上", [random.randint(50, 150) for _ in cate])
        .add_yaxis("门店", [random.randint(100, 200) for _ in cate])
        .set_global_opts(title_opts=opts.TitleOpts("手机品牌{}年营业额".format(i)))
    )
    tl.add(bar, "{}年".format(i))

tl.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="e1d9261bf3d9414eb598efcc053b21ac" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_e1d9261bf3d9414eb598efcc053b21ac = echarts.init(
#             document.getElementById('e1d9261bf3d9414eb598efcc053b21ac'), 'white', {renderer: 'canvas'});
#         var option_e1d9261bf3d9414eb598efcc053b21ac = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "bar",
#                 "name": "\u7ebf\u4e0a",
#                 "data": [
#                     124,
#                     99,
#                     65,
#                     66,
#                     135,
#                     147
#                 ],
#                 "barCategoryGap": "20%",
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8,
#                     "fontSize": 12
#                 }
#             },
#             {
#                 "type": "bar",
#                 "name": "\u95e8\u5e97",
#                 "data": [
#                     147,
#                     100,
#                     106,
#                     117,
#                     139,
#                     144
#                 ],
#                 "barCategoryGap": "20%",
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8,
#                     "fontSize": 12
#                 }
#             }
#         ],
#         "timeline": {
#             "axisType": "category",
#             "orient": "horizontal",
#             "autoPlay": false,
#             "loop": true,
#             "rewind": false,
#             "show": true,
#             "inverse": false,
#             "bottom": "-5px",
#             "data": [
#                 "2015\u5e74",
#                 "2016\u5e74",
#                 "2017\u5e74",
#                 "2018\u5e74",
#                 "2019\u5e74"
#             ]
#         },
#         "xAxis": [
#             {
#                 "show": true,
#                 "scale": false,
#                 "nameLocation": "end",
#                 "nameGap": 15,
#                 "gridIndex": 0,
#                 "inverse": false,
#                 "offset": 0,
#                 "splitNumber": 5,
#                 "minInterval": 0,
#                 "splitLine": {
#                     "show": false,
#                     "lineStyle": {
#                         "width": 1,
#                         "opacity": 1,
#                         "curveness": 0,
#                         "type": "solid"
#                     }
#                 },
#                 "data": [
#                     "Apple",
#                     "Huawei",
#                     "Xiaomi",
#                     "Oppo",
#                     "Vivo",
#                     "Meizu"
#                 ]
#             }
#         ],
#         "yAxis": [
#             {
#                 "show": true,
#                 "scale": false,
#                 "nameLocation": "end",
#                 "nameGap": 15,
#                 "gridIndex": 0,
#                 "inverse": false,
#                 "offset": 0,
#                 "splitNumber": 5,
#                 "minInterval": 0,
#                 "splitLine": {
#                     "show": false,
#                     "lineStyle": {
#                         "width": 1,
#                         "opacity": 1,
#                         "curveness": 0,
#                         "type": "solid"
#                     }
#                 }
#             }
#         ]
#     },
#     "options": [
#         {
#             "legend": [
#                 {
#                     "data": [
#                         "\u7ebf\u4e0a",
#                         "\u95e8\u5e97"
#                     ],
#                     "selected": {
#                         "\u7ebf\u4e0a": true,
#                         "\u95e8\u5e97": true
#                     },
#                     "show": true
#                 }
#             ],
#             "series": [
#                 {
#                     "data": [
#                         134,
#                         141,
#                         144,
#                         74,
#                         128,
#                         140
#                     ]
#                 },
#                 {
#                     "data": [
#                         184,
#                         180,
#                         160,
#                         183,
#                         105,
#                         169
#                     ]
#                 }
#             ],
#             "title": [
#                 {
#                     "text": "\u624b\u673a\u54c1\u724c2015\u5e74\u8425\u4e1a\u989d"
#                 }
#             ],
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0
#             }
#         },
#         {
#             "legend": [
#                 {
#                     "data": [
#                         "\u7ebf\u4e0a",
#                         "\u95e8\u5e97"
#                     ],
#                     "selected": {
#                         "\u7ebf\u4e0a": true,
#                         "\u95e8\u5e97": true
#                     },
#                     "show": true
#                 }
#             ],
#             "series": [
#                 {
#                     "data": [
#                         136,
#                         55,
#                         88,
#                         137,
#                         101,
#                         134
#                     ]
#                 },
#                 {
#                     "data": [
#                         140,
#                         168,
#                         109,
#                         176,
#                         179,
#                         146
#                     ]
#                 }
#             ],
#             "title": [
#                 {
#                     "text": "\u624b\u673a\u54c1\u724c2016\u5e74\u8425\u4e1a\u989d"
#                 }
#             ],
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0
#             }
#         },
#         {
#             "legend": [
#                 {
#                     "data": [
#                         "\u7ebf\u4e0a",
#                         "\u95e8\u5e97"
#                     ],
#                     "selected": {
#                         "\u7ebf\u4e0a": true,
#                         "\u95e8\u5e97": true
#                     },
#                     "show": true
#                 }
#             ],
#             "series": [
#                 {
#                     "data": [
#                         52,
#                         107,
#                         69,
#                         90,
#                         100,
#                         141
#                     ]
#                 },
#                 {
#                     "data": [
#                         127,
#                         130,
#                         119,
#                         166,
#                         200,
#                         157
#                     ]
#                 }
#             ],
#             "title": [
#                 {
#                     "text": "\u624b\u673a\u54c1\u724c2017\u5e74\u8425\u4e1a\u989d"
#                 }
#             ],
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "textStyle": {
#                     "fontSize": 14
#                 },

# %%
#航线图
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.globals import ChartType, SymbolType, ThemeType
import requests
r = requests.get('https://echarts.baidu.com/examples/data-gl/asset/data/flights.json')
data = r.json()
city = ['Beijing']
airports_code = []

geo = Geo(init_opts=opts.InitOpts(theme=ThemeType.DARK))
for i, airport in enumerate(data['airports']):
    if airport[1] in city:
        geo.add_coordinate(i, airport[3], airport[4])
        airports_code.append(i)

route = [(x, y) for _, x, y in data['routes'] if x in airports_code]


geo.add_schema(maptype="world",
                itemstyle_opts=opts.ItemStyleOpts())
geo.add("geo", route, 
        is_large = True,
        symbol_size=0,
        type_='lines',
        is_polyline=True,
        effect_opts=opts.EffectOpts(symbol='pin', symbol_size=1, trail_length=1, color="rgba(255,69,0,0.9)"),
        linestyle_opts=opts.LineStyleOpts(curve=0.2, width=0.2, color='rgb(245,245,245)',opacity=0.05)
       )
geo.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
geo.set_global_opts(title_opts=opts.TitleOpts(title="北京发出所有航线"),
                   legend_opts=opts.LegendOpts(is_show=False))


geo.render_notebook()
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# C:\自装\python3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     170             conn = connection.create_connection(
# --> 171                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     172
#
# C:\自装\python3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      78     if err is not None:
# ---> 79         raise err
#      80
#
# C:\自装\python3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      68                 sock.bind(source_address)
# ---> 69             sock.connect(sa)
#      70             return sock
#
# TimeoutError: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# C:\自装\python3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# C:\自装\python3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# C:\自装\python3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     848         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 849             conn.connect()
#     850
#
# C:\自装\python3\lib\site-packages\urllib3\connection.py in connect(self)
#     313         # Add certificate verification
# --> 314         conn = self._new_conn()
#     315
#
# C:\自装\python3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     179             raise NewConnectionError(
# --> 180                 self, "Failed to establish a new connection: %s" % e)
#     181
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x0000022AD9F2A518>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# C:\自装\python3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     444                     retries=self.max_retries,
# --> 445                     timeout=timeout
#     446                 )
#
# C:\自装\python3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# C:\自装\python3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPSConnectionPool(host='echarts.baidu.com', port=443): Max retries exceeded with url: /examples/data-gl/asset/data/flights.json (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000022AD9F2A518>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-16-ec2137997c44> in <module>()
#       3 from pyecharts.globals import ChartType, SymbolType, ThemeType
#       4 import requests
# ----> 5 r = requests.get('https://echarts.baidu.com/examples/data-gl/asset/data/flights.json')
#       6 data = r.json()
#       7 city = ['Beijing']
#
# C:\自装\python3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# C:\自装\python3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# C:\自装\python3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     510         }
#     511         send_kwargs.update(settings)
# --> 512         resp = self.send(prep, **send_kwargs)
#     513
#     514         return resp
#
# C:\自装\python3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     620
#     621         # Send the request
# --> 622         r = adapter.send(request, **kwargs)
#     623
#     624         # Total elapsed time of the request (approximately)
#
# C:\自装\python3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     511                 raise SSLError(e, request=request)
#     512
# --> 513             raise ConnectionError(e, request=request)
#     514
#     515         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='echarts.baidu.com', port=443): Max retries exceeded with url: /examples/data-gl/asset/data/flights.json (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000022AD9F2A518>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。',))

# %%
#气泡效果散点图
from pyecharts import options as opts
from pyecharts.charts import Scatter
from pyecharts.globals import ThemeType
from pyecharts.commons.utils import JsCode

# 人均寿命于GDP
data = [[[28604,77,17096869,'Australia',1990],[31163,77.4,27662440,'Canada',1990],[1516,68,1154605773,'China',1990],[13670,74.7,10582082,'Cuba',1990],[28599,75,4986705,'Finland',1990],[29476,77.1,56943299,'France',1990],[31476,75.4,78958237,'Germany',1990],[28666,78.1,254830,'Iceland',1990],[1777,57.7,870601776,'India',1990],[29550,79.1,122249285,'Japan',1990],[2076,67.9,20194354,'North Korea',1990],[12087,72,42972254,'South Korea',1990],[24021,75.4,3397534,'New Zealand',1990],[43296,76.8,4240375,'Norway',1990],[10088,70.8,38195258,'Poland',1990],[19349,69.6,147568552,'Russia',1990],[10670,67.3,53994605,'Turkey',1990],[26424,75.7,57110117,'United Kingdom',1990],[37062,75.4,252847810,'United States',1990]],
    [[44056,81.8,23968973,'Australia',2015],[43294,81.7,35939927,'Canada',2015],[13334,76.9,1376048943,'China',2015],[21291,78.5,11389562,'Cuba',2015],[38923,80.8,5503457,'Finland',2015],[37599,81.9,64395345,'France',2015],[44053,81.1,80688545,'Germany',2015],[42182,82.8,329425,'Iceland',2015],[5903,66.8,1311050527,'India',2015],[36162,83.5,126573481,'Japan',2015],[1390,71.4,25155317,'North Korea',2015],[34644,80.7,50293439,'South Korea',2015],[34186,80.6,4528526,'New Zealand',2015],[64304,81.6,5210967,'Norway',2015],[24787,77.3,38611794,'Poland',2015],[23038,73.13,143456918,'Russia',2015],[19360,76.5,78665830,'Turkey',2015],[38225,81.4,64715810,'United Kingdom',2015],[53354,79.1,321773631,'United States',2015]]]
scatter = (Scatter()
           .add_xaxis([i[0] for i in data[0]])
           .add_yaxis("1990年", [[i[1],i[3], i[2]] for i in data[0]],
                      # 渐变效果实现部分
                      color=JsCode("""new echarts.graphic.RadialGradient(0.4, 0.3, 1, [{
                                        offset: 0,
                                        color: 'rgb(251, 118, 123)'
                                    }, {
                                        offset: 1,
                                        color: 'rgb(204, 46, 72)'
                                    }])"""))
           .add_yaxis("2015年", [[i[1],i[3], i[2]]  for i in data[1]], 
                      # 渐变效果实现部分
                      color=JsCode("""new echarts.graphic.RadialGradient(0.4, 0.3, 1, [{
                                        offset: 0,
                                        color: 'rgb(129, 227, 238)'
                                    }, {
                                        offset: 1,
                                        color: 'rgb(25, 183, 207)'
                                    }])"""))
           .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
           .set_global_opts(
               title_opts=opts.TitleOpts(title="1990 与 2015 年各国家人均寿命与 GDP"),
               tooltip_opts = opts.TooltipOpts(
                   # 通过执行js代码实现提示显示为国家
                   formatter=JsCode("function (param) {return param.data[2];}")),
               xaxis_opts=opts.AxisOpts(
                   # 设置坐标轴为数值类型
                   type_="value", 
                   # 显示分割线
                   splitline_opts=opts.SplitLineOpts(is_show=True)),
               yaxis_opts=opts.AxisOpts(
                   # 设置坐标轴为数值类型
                   type_="value",
                   # 默认为False表示起始为0
                   is_scale=True,
                   splitline_opts=opts.SplitLineOpts(is_show=True),),
               # 数据中第三个度量值通过图形的size来展示
               visualmap_opts=opts.VisualMapOpts(is_show=False, type_='size', min_=20194354, max_=1154605773)
    ))

scatter.render_notebook()
